# %%
import os
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, ResNet50, EfficientNetB0

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Verify Dataset Programmatically (Before Training)

# %%
import os

DATASET_DIR = r"C:\Users\LENOVO P14S\6th-Sem-Project\dataset"

classes = os.listdir(DATASET_DIR)
print("Classes:", classes)

for cls in classes:
    cls_path = os.path.join(DATASET_DIR, cls)
    print(f"{cls}: {len(os.listdir(cls_path))} images")
# Out:
# Classes: ['ripen', 'unripen']
# ripen: 388 images
# unripen: 629 images

# %% [markdown]
# # Load Images the RIGHT Way
# #### This alone: Labels your data
# #### Splits train/validation
# #### Resizes images
# #### Builds an efficient pipeline

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 16

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
print("Class names:", class_names)
# Out:
# Found 1017 files belonging to 2 classes.
# Using 814 files for training.
# Found 1017 files belonging to 2 classes.
# Using 203 files for validation.
# Class names: ['ripen', 'unripen']

# %% [markdown]
# # Normalize Images
# ### Neural networks do not like raw pixel values.

# %%
# normalization_layer = tf.keras.layers.Rescaling(1./255)

# train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# # Visual Sanity Check

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [10.0713825..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %% [markdown]
# # Class Imbalance

# %%
class_weight = {
    0: 629 / 388,   # ripen
    1: 1.0          # unripen
}

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %% [markdown]
# # Build the Model
# ### Step 1: Load Base Model

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False

# %% [markdown]
# ### Step 2: Custom Classification Head
# #### Binary problem → sigmoid

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

# %% [markdown]
# ### Step 3: Compile

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy","precision","Recall"]
)

# %% [markdown]
# # Train (Phase 1: Feature Extraction)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    class_weight=class_weight
)
# Out:
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 241ms/step - Recall: 0.7605 - accuracy: 0.7592 - loss: 0.7426 - precision: 0.8337 - val_Recall: 0.6875 - val_accuracy: 0.7438 - val_loss: 0.4974 - val_precision: 0.8800
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - Recall: 0.8004 - accuracy: 0.8194 - loss: 0.5432 - precision: 0.8951 - val_Recall: 0.7812 - val_accuracy: 0.7685 - val_loss: 0.4792 - val_precision: 0.8403
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - Recall: 0.8343 - accuracy: 0.8329 - loss: 0.5003 - precision: 0.8875 - val_Recall: 0.8125 - val_accuracy: 0.7635 - val_loss: 0.4687 - val_precision: 0.8125
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - Recall: 0.8423 - accuracy: 0.8452 - loss: 0.4651 - precision: 0.8998 - val_Recall: 0.8281 - val_accuracy: 0.7783 - val_loss: 0.4745 - val_precision: 0.8217
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - Recall: 0.8423 - accuracy: 0.8514 - loss: 0.4247 - precision: 0.9095 - val_Recall: 0.7891 - val_accuracy: 0.7537 - val_loss: 0.5062 - val_precision: 0.8145
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - Recall: 0.8603 - accuracy: 0.8636 - loss: 0.3855 - precision: 0.9131 - val_Recall: 0.8359 - val_accuracy: 0.7882 - val_loss: 0.4695 - val_precision: 0.8295
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - Recall: 0.8623 - accuracy: 0.8600 - loss: 0.4090 - precision: 0.9057 - val_Recall: 0.8047 - val_accuracy: 0.7635 - val_loss: 0.4797 - val_precision: 0.8175
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - Recall: 0.8583 - accuracy: 0.8673 - loss: 0.3562 - precision: 0.9208 - val_Recall: 0.8516 - val_accuracy: 0.8030 - val_loss: 0.5129 - val_precision: 0.8385
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - Recall: 0.8483 - accuracy: 0.8612 - loss: 0.3881 - precision: 0.9199 - val_Recall: 0.8125 - val_accuracy: 0.7734 - val_loss: 0.5474 - val_precision: 0.8254
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - Recall: 0.8762 - accuracy: 0.8857 - loss: 0.3485 - precision: 0.9340 - val_Recall: 0.8125 - val_accuracy: 0.7783 - val_loss: 0.5412 - val_precision: 0.8320

# %% [markdown]
# # CONFUSION MATRIX
# ### Step 1: Collect true labels and predictions

# %%
import numpy as np

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int).flatten()

    y_true.extend(labels.numpy())
    y_pred.extend(preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# ### Step 2: Generate confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=["Ripen", "Unripen"],
            yticklabels=["Ripen", "Unripen"],
            cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # PRECISION, RECALL, F1

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    target_names=["Ripen", "Unripen"]
))
# Out:
#               precision    recall  f1-score   support
#
#        Ripen       0.69      0.72      0.71        75
#      Unripen       0.83      0.81      0.82       128
#
#     accuracy                           0.78       203
#    macro avg       0.76      0.77      0.76       203
# weighted avg       0.78      0.78      0.78       203

# %% [markdown]
# # FINAL MODEL SAVING

# %%
model.save("arecanut_maturity.keras")

# %% [markdown]
# # TENSORFLOW LITE CONVERSION

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()

with open("arecanut_maturity.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\LENOVO~1\AppData\Local\Temp\tmptg5a02op\assets
# INFO:tensorflow:Assets written to: C:\Users\LENOVO~1\AppData\Local\Temp\tmptg5a02op\assets
# Saved artifact at 'C:\Users\LENOVO~1\AppData\Local\Temp\tmptg5a02op'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   3045605802640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606203728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045605802448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045605806480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606202000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606199504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606208720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606206800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606206992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606207184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606211216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606208528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606211408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643912784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643915088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643913168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643912976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644632144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644632720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644633488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644633296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644633680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644632336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644632912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644634256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644634064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644633104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644634448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644634832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644635408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644635216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644633872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644635600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644635984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644636752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644636944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644632528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644636176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644637712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644637520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644637904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644637136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644638672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644638480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644638864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644636368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644638096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644639632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644639440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644639824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644637328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644639056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644638288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644641552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644641360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644641744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644639248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644641936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644642704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644642512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644643088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644643856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644643664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644644048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644642128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644643280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644644816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644644624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644640208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644644240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644643472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644646736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644646544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644646928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644644432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644646160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644647696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644647504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644647888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644645392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644648080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644647312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045644648272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607063824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607065744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607065552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607065936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607065168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607066704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607066512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607066896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607064400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607066128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607067664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607067472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607067856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607065360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607067088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607068432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607068816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607066320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607068048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607067280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607070352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607070736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607068240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607071504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607071312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607069200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607070928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607072272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607072656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607071888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607073424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607073232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607071120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607073808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607075344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607075152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607075536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607073040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607076304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607076112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607075728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607077264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607077072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607077456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607074960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607076688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607075920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607077648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607079184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607079376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607076880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607079568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607077840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607078800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045607079760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608014288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608014864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608015248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608014096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608014480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608013904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045643922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045605804176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606206224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045605803984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045605804368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606205840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608015440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608015632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045606206032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608015824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608017168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608017360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608017936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608018320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608014672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608017552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608019280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608018512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608020048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608020240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608017744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608020816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608018704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608020432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608022160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608022928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608022736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608023120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608020624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608022352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608023888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608023696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608024080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608021584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608023312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608024848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608024656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608025040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608022544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608026192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608025808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608026000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608025424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608026768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608027728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608027344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3045608028304: TensorSpec(shape=(), dtype=tf.resource, name=None)
